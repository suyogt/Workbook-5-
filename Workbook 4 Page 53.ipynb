# %%
import pandas as pd

# %%
import numpy as np

# %%
Location = "C:/Users/Suyog Thengale/Desktop/datasets/gradedata.csv"

# %%
df = pd.read_csv(Location)

# %%
df.tail()
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address
# 1995        982 West Street, Alexandria, VA 22304
# 1996   78 Morris Street, East Northport, NY 11731
# 1997        30 Glenridge Rd., Bountiful, UT 84010
# 1998  342 West Meadowbrook Lane, Helena, MT 59601
# 1999       81 Homestead Drive, Voorhees, NJ 08043

# %%
df.take(np.random.permutation(len(df))[:500])
# Out:
#          fname    lname  gender  age  exercise  hours  grade  \
# 474       Dana     Vang  female   17         4     14   88.7
# 706      Mason    Burke    male   14         4     10   84.3
# 1675  Vladimir     Rose    male   19         5     13   84.1
# 1398     Halla     Vang  female   16         3     17  100.0
# 703     Steven    Hayes    male   15         4     14   88.7
# ...        ...      ...     ...  ...       ...    ...    ...
# 1298     Erica     Bond  female   15         3     16  100.0
# 1054      Mari     Holt  female   16         2     11   76.1
# 1928    Jarrod   Strong    male   14         3     11   76.1
# 1961      Nero  Kennedy    male   14         4     14   88.3
# 514       Kirk   Keller    male   16         4      6   77.0
#
#                                             address
# 474         80 Wild Horse Ave., Baltimore, MD 21206
# 706              831 Adams St., Lumberton, NC 28358
# 1675      3 Sherman Street, Nicholasville, KY 40356
# 1398       9124 Fairway Road, Dawsonville, GA 30534
# 703   7840 Harvard Court, Jackson Heights, NY 11372
# ...                                             ...
# 1298      38 Mechanic Street, New Milford, CT 06776
# 1054        62 Green Hill St., Oconomowoc, WI 53066
# 1928      193 Riverside Street, Fort Mill, SC 29708
# 1961          63 Manor St., Saint Charles, IL 60174
# 514             7334 Pine St., Lake Worth, FL 33460
#
# [500 rows x 8 columns]
